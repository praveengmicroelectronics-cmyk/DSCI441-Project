# %%
import os

os.system("kaggle datasets download -d qingyi/wm811k-wafer-map")
os.system("unzip wm811k-wafer-map.zip")
# Out:
# sh: kaggle: command not found
# unzip:  cannot find or open wm811k-wafer-map.zip, wm811k-wafer-map.zip.zip or wm811k-wafer-map.zip.ZIP.
# 2304
